# %%
class Smartphone():

  def __init__(self, tamanho, interface):
    self.tamanho = tamanho
    self.interface = interface
    print('Dispositivo criado')


class MP3Player(Smartphone):
  def __init__(self, tamanho = 'pequeno', interface='led', capacidade = '64GB'):
    self.capacidade = capacidade
    Smartphone.__init__(self, tamanho, interface)
    print('MP3 Criado')

  def print_MP3Player(self):
        print(f"Valores para o objeto criado:{self.tamanho}, {self.interface}, {self.capacidade}")
    
device1 = MP3Player()
device1.print_MP3Player()
# Out:
# Dispositivo criado
# MP3 Criado
# Valores para o objeto criado:pequeno, led, 64GB
